# %%
import pandas as pd

train = pd.read_csv("train.csv")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train[["Sex"]].describe()
# Out:
#          Sex
# count    891
# unique     2
# top     male
# freq     577

# %%
train.groupby('Sex')[["Age"]].describe()
# Out:
#           Age
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
train.groupby('SibSp')[["Sex"]].describe()
# Out:
#         Sex
#       count unique     top freq
# SibSp
# 0       608      2    male  434
# 1       209      2  female  106
# 2        28      2    male   15
# 3        16      2  female   11
# 4        18      2    male   12
# 5         5      2    male    4
# 8         7      2    male    4

# %%
train.groupby('Pclass')[["Cabin"]].describe()
# Out:
#        Cabin
#        count unique      top freq
# Pclass
# 1        176    133  B96 B98    4
# 2         16      7      F33    3
# 3         12      7       G6    4

# %%
train.groupby('SibSp')[["Cabin"]].describe()
# Out:
#       Cabin
#       count unique          top freq
# SibSp
# 0       126    102            D    3
# 1        69     45      B96 B98    4
# 2         6      4           F4    2
# 3         3      1  C23 C25 C27    3
# 4         0      0          NaN  NaN
# 5         0      0          NaN  NaN
# 8         0      0          NaN  NaN

# %%
train.groupby('Fare')[["Ticket"]].describe()
# Out:
#          Ticket
#           count unique       top freq
# Fare
# 0.0000       15     10      LINE    4
# 4.0125        1      1      2648    1
# 5.0000        1      1       695    1
# 6.2375        1      1    345364    1
# 6.4375        1      1      2683    1
# ...         ...    ...       ...  ...
# 227.5250      4      1  PC 17757    4
# 247.5208      2      1  PC 17558    2
# 262.3750      2      1  PC 17608    2
# 263.0000      4      1     19950    4
# 512.3292      3      1  PC 17755    3
#
# [248 rows x 4 columns]

# %%
train.groupby('Embarked')[["Pclass"]].describe()
# Out:
#          Pclass
#           count      mean       std  min  25%  50%  75%  max
# Embarked
# C         168.0  1.886905  0.944100  1.0  1.0  1.0  3.0  3.0
# Q          77.0  2.909091  0.369274  1.0  3.0  3.0  3.0  3.0
# S         644.0  2.350932  0.789402  1.0  2.0  3.0  3.0  3.0

# %%
train.groupby('Pclass')[["Fare"]].describe()
# Out:
#          Fare
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
# %matplotlib inline
train.plot(kind='scatter',x='Fare',y='Age')
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
train.plot(kind='scatter',x='Survived',y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
train['Age'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
train.groupby('Pclass')[["Embarked"]].value_counts().unstack().plot(kind="bar",stacked=True,figsize=(10,6))
# Out:
# <Axes: xlabel='Pclass'>

# %%
train.groupby('Pclass')[["SibSp"]].value_counts().unstack().plot(kind="bar",stacked=True,figsize=(10,6))
# Out:
# <Axes: xlabel='Pclass'>

# %%
train.groupby('Pclass')[["Survived"]].value_counts().unstack().plot(kind="bar",stacked=True,figsize=(10,6))
# Out:
# <Axes: xlabel='Pclass'>

# %%
mask =
